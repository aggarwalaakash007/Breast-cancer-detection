# %%
import math
from collections import Counter
import pickle
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from PIL import Image
from breast_cancer import *
from tqdm import tqdm
import cv2
# %matplotlib inline
name = []
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from scipy.misc import imread
import matplotlib.pyplot as plt
import numpy as np
import keras
from keras.layers import Dense
import pandas as pd
from keras import backend as K
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input
import numpy as np
from keras.applications.resnet50 import decode_predictions

# %%
filename = 'benign3.png'
array = image_array(filename, 224)
y, feature = prediction(array)
print('Our Prediction: ', y)
array = cv2.imread(filename)
print('Showing Feature Extracted by ResNet50 model')
features(feature)

plt.imshow(array, cmap = 'gray')
plt.show
print('Orignal picture')
# Out:
# Benign Probability:  0.99991167
# Malignant Probability:  8.829037e-05
# Our Prediction:  Benign
# Showing Feature Extracted by ResNet50 model
# Orignal picture
